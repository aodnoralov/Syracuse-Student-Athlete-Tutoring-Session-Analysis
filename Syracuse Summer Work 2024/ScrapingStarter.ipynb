# %%
### Driver
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %%
driver = webdriver.Chrome()
url = 'https://twitter.com/home'
driver.get(url)
# driver.implicitly_wait(5)
soup = BeautifulSoup(driver.page_source, 'lxml')
tables = soup.find_all('table')
dfs = pd.read_html(str(tables))
#links = soup.find_all('a',{'target':"_self"})

# %%
dfs[0]
# Out:
#      No.                  Player Pos    Ht   Wt         Birth Date Unnamed: 6  \
# 0    9.0           Derrick White  SG   6-4  190       July 2, 1994         us
# 1   30.0              Sam Hauser  PF   6-8  215   December 8, 1997         us
# 2   12.0          Grant Williams  PF   6-6  236  November 30, 1998         us
# 3    0.0            Jayson Tatum  PF   6-8  210      March 3, 1998         us
# 4   40.0             Luke Kornet   C   7-2  250      July 15, 1995         us
# 5    7.0            Jaylen Brown  SF   6-6  223   October 24, 1996         us
# 6   13.0         Malcolm Brogdon  PG   6-5  229  December 11, 1992         us
# 7   42.0              Al Horford   C   6-9  240       June 3, 1986         do
# 8   36.0            Marcus Smart  PG   6-3  220      March 6, 1994         us
# 9   11.0        Payton Pritchard  PG   6-1  195   January 28, 1998         us
# 10  91.0           Blake Griffin   C   6-9  250     March 16, 1989         us
# 11  44.0         Robert Williams   C   6-9  237   October 17, 1997         us
# 12  57.0            Mike Muscala   C  6-10  240       July 1, 1991         us
# 13  20.0         JD Davison (TW)  PG   6-3  195    October 3, 2002         us
# 14  28.0  Mfiondu Kabengele (TW)  PF   6-9  250    August 14, 1997         ca
# 15  99.0       Justin Champagnie  SF   6-6  200      June 29, 2001         us
# 16   NaN        Danilo Gallinari  SF  6-10  233     August 8, 1988         it
#
#    Exp                              College
# 0    5  Colorado-Colorado Springs, Colorado
# 1    1                  Marquette, Virginia
# 2    3                            Tennessee
# 3    5                                 Duke
# 4    5                           Vanderbilt
# 5    6                           California
# 6    6                             Virginia
# 7   15                              Florida
# 8    8                       Oklahoma State
# 9    2                               Oregon
# 10  12                             Oklahoma
# 11   4                            Texas A&M
# 12   9                             Bucknell
# 13   R                              Alabama
# 14   2                        Florida State
# 15   1                                 Pitt
# 16  13                                  NaN

# %%
### HTML
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.basketball-reference.com/teams/ATL/2022.html'
html = urlopen(url)
bs = BeautifulSoup(html.read(), 'lxml')
tables = bs.find_all('table',{"id":"roster"})
results1 = pd.read_html(str(tables))
